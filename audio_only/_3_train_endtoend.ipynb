# %%
python main.py \
    --nClasses 500 \
    --path './backendGRU_every_frame/backendGRU_27.pt' \
    --dataset '/media/ikesan009/E/lipread_mat/' \
    --mode 'finetuneGRU' \
    --every-frame 'True' \
    --batch-size 180 \
    --lr 3e-4 \
    --startepoch 1 \
    --endepoch 30 \
    --test ''
# Out:
# *** model has been successfully loaded! ***
# Load train part
# Load val part
# Load test part
#
# Statistics: train: 50000, val: 25000, test: 25000
# ----------
# Epoch 0/29
# Current Learning rate: [0.0003]
# main.py:98: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   running_loss += loss.data[0] * inputs.size(0)
# Process: [ 1980/50000 (4%)]	Loss: 0.4541	Acc:0.8808	Cost time:    8s	Estimated time:  209s
# Process: [ 3780/50000 (7%)]	Loss: 0.4448	Acc:0.8770	Cost time:   16s	Estimated time:  202s
# Process: [ 5580/50000 (11%)]	Loss: 0.4382	Acc:0.8753	Cost time:   24s	Estimated time:  194s
# Process: [ 7380/50000 (14%)]	Loss: 0.4110	Acc:0.8840	Cost time:   32s	Estimated time:  187s
# Process: [ 9180/50000 (18%)]	Loss: 0.3981	Acc:0.8892	Cost time:   40s	Estimated time:  179s
# Process: [10980/50000 (22%)]	Loss: 0.3841	Acc:0.8937	Cost time:   48s	Estimated time:  172s
# ...
