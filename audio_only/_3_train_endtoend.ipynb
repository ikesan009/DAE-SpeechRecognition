# %%
python main.py \
    --nClasses 5 \
    --path './backendGRU_every_frame/backendGRU_5.pt' \
    --dataset './lipread_mat/' \
    --mode 'finetuneGRU' \
    --every-frame 'True' \
    --batch-size 36 \
    --lr 3e-4 \
    --epochs 30 \
    --test ''
# Out:
# *** model has been successfully loaded! ***
# Load train part
# Load val part
# Load test part
#
# Statistics: train: 4956, val: 250, test: 250
# ----------
# Epoch 0/29
# Current Learning rate: [0.0003]
# main.py:96: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   running_loss += loss.data[0] * inputs.size(0)
# Process: [  396/ 4956 (7%)]	Loss: 0.2888	Acc:0.0000	Cost time:    2s	Estimated time:   21s
# Process: [  756/ 4956 (15%)]	Loss: 0.2087	Acc:0.0000	Cost time:    3s	Estimated time:   19s
# Process: [ 1116/ 4956 (22%)]	Loss: 0.1696	Acc:0.0000	Cost time:    5s	Estimated time:   17s
# Process: [ 1476/ 4956 (29%)]	Loss: 0.1498	Acc:0.0000	Cost time:    6s	Estimated time:   16s
# Process: [ 1836/ 4956 (36%)]	Loss: 0.1407	Acc:0.0000	Cost time:    8s	Estimated time:   14s
# Process: [ 2196/ 4956 (44%)]	Loss: 0.1328	Acc:0.0000	Cost time:   10s	Estimated time:   12s
# ...
