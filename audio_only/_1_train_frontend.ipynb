# %%
python main.py \
    --nClasses 5 \
    --path '' \
    --dataset './lipread_mat/' \
    --mode 'temporalConv' \
    --every-frame '' \
    --batch-size 36 \
    --lr 3e-4 \
    --epochs 30 \
    --test ''
# Out:
# train from scratch
# Load train part
# Load val part
# Load test part
#
# Statistics: train: 4956, val: 250, test: 250
# ----------
# Epoch 0/29
# Current Learning rate: [0.0003]
# main.py:96: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   running_loss += loss.data[0] * inputs.size(0)
# Process: [  396/ 4956 (7%)]	Loss: 1.0536	Acc:0.0000	Cost time:    2s	Estimated time:   20s
# Process: [  756/ 4956 (15%)]	Loss: 0.8005	Acc:0.0000	Cost time:    3s	Estimated time:   19s
# Process: [ 1116/ 4956 (22%)]	Loss: 0.6339	Acc:0.0000	Cost time:    5s	Estimated time:   17s
# Process: [ 1476/ 4956 (29%)]	Loss: 0.5385	Acc:0.0000	Cost time:    6s	Estimated time:   15s
# Process: [ 1836/ 4956 (36%)]	Loss: 0.4679	Acc:0.0000	Cost time:    8s	Estimated time:   14s
# Process: [ 2196/ 4956 (44%)]	Loss: 0.4155	Acc:0.0000	Cost time:   10s	Estimated time:   12s
# ...
