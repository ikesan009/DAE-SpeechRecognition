# %%
python main.py \
    --nClasses 50 \
    --path '' \
    --dataset '/media/ikesan009/B418B4D718B499B6/Projects/research/Dataset/lipread_mat/' \
    --mode 'temporalConv' \
    --every-frame '' \
    --batch-size 180 \
    --lr 3e-4 \
    --epochs 30 \
    --test ''
# Out:
# train from scratch
# Load train part
# Load val part
# Load test part
#
# Statistics: train: 48858, val: 2500, test: 2500
# ----------
# Epoch 0/29
# Current Learning rate: [0.0003]
# main.py:98: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   running_loss += loss.data[0] * inputs.size(0)
# Process: [ 1980/48858 (4%)]	Loss: 3.7012	Acc:0.0000	Cost time:  132s	Estimated time: 3448s
# Process: [ 3780/48858 (7%)]	Loss: 3.4568	Acc:0.0000	Cost time:  265s	Estimated time: 3324s
# Process: [ 5580/48858 (11%)]	Loss: 3.2107	Acc:0.0000	Cost time:  398s	Estimated time: 3198s
# Process: [ 7380/48858 (15%)]	Loss: 2.9979	Acc:0.0000	Cost time:  651s	Estimated time: 3757s
# Process: [ 9180/48858 (18%)]	Loss: 2.8012	Acc:0.0000	Cost time:  782s	Estimated time: 3457s
# Process: [10980/48858 (22%)]	Loss: 2.6273	Acc:0.0000	Cost time:  909s	Estimated time: 3196s
# ...
