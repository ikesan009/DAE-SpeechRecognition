# %%
python main.py \
    --nClasses 500 \
    --path './temporalConv/temporalConv_30.pt' \
    --dataset '/media/ikesan009/E/lipread_mat/' \
    --mode 'backendGRU' \
    --every-frame 'True' \
    --batch-size 180 \
    --lr 3e-4 \
    --startepoch 1 \
    --endepoch 30 \
    --test ''
# Out:
# *** model has been successfully loaded! ***
# Load train part
# Load val part
# Load test part
#
# Statistics: train: 50000, val: 25000, test: 25000
# ----------
# Epoch 0/29
# Current Learning rate: [0.0003]
# main.py:98: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   running_loss += loss.data[0] * inputs.size(0)
# Process: [ 1980/50000 (4%)]	Loss: 6.2550	Acc:0.0025	Cost time:    3s	Estimated time:   72s
# Process Process-3:
# Process Process-4:
# Process Process-5:
# Process Process-7:
# Process Process-1:
# Process Process-6:
# Process Process-2:
# Process Process-8:
# Traceback (most recent call last):
#   File "/home/ikesan009/anaconda3/lib/python3.6/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/home/ikesan009/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# ...
