# %%
python main.py \
    --nClasses 5 \
    --path './temporalConv/temporalConv_29.pt' \
    --dataset './lipread_mat/' \
    --mode 'backendGRU' \
    --every-frame 'True' \
    --batch-size 72 \
    --lr 3e-4 \
    --epochs 5 \
    --test ''
# Out:
# *** model has been successfully loaded! ***
# Load train part
# Load val part
# Load test part
#
# Statistics: train: 4956, val: 250, test: 250
# ----------
# Epoch 0/4
# Current Learning rate: [0.0003]
# main.py:96: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   running_loss += loss.data[0] * inputs.size(0)
# Process: [  792/ 4956 (15%)]	Loss: 1.2872	Acc:0.0000	Cost time:    1s	Estimated time:    7s
# Process: [ 1512/ 4956 (29%)]	Loss: 1.0572	Acc:0.0000	Cost time:    2s	Estimated time:    5s
# Process: [ 2232/ 4956 (44%)]	Loss: 0.8985	Acc:0.0000	Cost time:    3s	Estimated time:    4s
# Process: [ 2952/ 4956 (59%)]	Loss: 0.7756	Acc:0.0000	Cost time:    5s	Estimated time:    3s
# Process: [ 3672/ 4956 (74%)]	Loss: 0.6948	Acc:0.0000	Cost time:    6s	Estimated time:    2s
# Process: [ 4392/ 4956 (88%)]	Loss: 0.6263	Acc:0.0000	Cost time:    7s	Estimated time:    1s
# ...
