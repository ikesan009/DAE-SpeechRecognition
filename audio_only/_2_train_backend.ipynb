# %%
python main.py \
    --nClasses 50 \
    --path './temporalConv/temporalConv_30.pt' \
    --dataset '/media/ikesan009/B418B4D718B499B6/Projects/research/Dataset/lipread_mat/' \
    --mode 'backendGRU' \
    --every-frame 'True' \
    --batch-size 180 \
    --lr 3e-4 \
    --epochs 30 \
    --test ''
# Out:
# *** model has been successfully loaded! ***
# Load train part
# Load val part
# Load test part
#
# Statistics: train: 48858, val: 2500, test: 2500
# ----------
# Epoch 0/29
# Current Learning rate: [0.0003]
# main.py:98: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   running_loss += loss.data[0] * inputs.size(0)
# Process: [ 1980/48858 (4%)]	Loss: 3.8185	Acc:0.0515	Cost time:   41s	Estimated time: 1064s
# Process: [ 3780/48858 (7%)]	Loss: 3.6629	Acc:0.0886	Cost time:  107s	Estimated time: 1342s
# Process: [ 5580/48858 (11%)]	Loss: 3.5285	Acc:0.1129	Cost time:  175s	Estimated time: 1408s
# Process: [ 7380/48858 (15%)]	Loss: 3.3951	Acc:0.1398	Cost time:  302s	Estimated time: 1746s
# Process: [ 9180/48858 (18%)]	Loss: 3.2721	Acc:0.1647	Cost time:  373s	Estimated time: 1650s
# Process: [10980/48858 (22%)]	Loss: 3.1726	Acc:0.1853	Cost time:  443s	Estimated time: 1559s
# ...
