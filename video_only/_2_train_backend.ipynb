# %%
python main.py \
    --nClasses 5 \
    --path './temporalConv/temporalConv_29.pt' \
    --dataset './lipread_npy/' \
    --mode 'backendGRU' \
    --every-frame 'True' \
    --batch-size 72 \
    --lr 3e-4 \
    --epochs 5 \
    --test ''
# Out:
# *** model has been successfully loaded! ***
# Load train part
# Load val part
# Load test part
#
# Statistics: train: 4959, val: 250, test: 250
# ----------
# Epoch 0/4
# Current Learning rate: [0.0003]
# main.py:109: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   running_loss += loss.data[0] * inputs.size(0)
# Process: [  792/ 4959 (15%)]	Loss: 1.2860	Acc:0.0000	Cost time:    6s	Estimated time:   36s
# Process: [ 1512/ 4959 (29%)]	Loss: 1.1732	Acc:0.0000	Cost time:   12s	Estimated time:   30s
# Process: [ 2232/ 4959 (44%)]	Loss: 1.0549	Acc:0.0000	Cost time:   19s	Estimated time:   23s
# Process: [ 2952/ 4959 (59%)]	Loss: 0.9601	Acc:0.0000	Cost time:   25s	Estimated time:   17s
# Process: [ 3672/ 4959 (74%)]	Loss: 0.8778	Acc:0.0000	Cost time:   31s	Estimated time:   11s
# Process: [ 4392/ 4959 (88%)]	Loss: 0.8176	Acc:0.0000	Cost time:   37s	Estimated time:    5s
# ...
