# %%
python main.py \
    --nClasses 5 \
    --path '' \
    --dataset './lipread_npy/' \
    --mode 'temporalConv' \
    --every-frame '' \
    --batch-size 25 \
    --lr 3e-4 \
    --epochs 30 \
    --test ''
# Out:
# train from scratch
# Load train part
# Load val part
# Load test part
#
# Statistics: train: 4959, val: 250, test: 250
# ----------
# Epoch 0/29
# Current Learning rate: [0.0003]
# main.py:109: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   running_loss += loss.data[0] * inputs.size(0)
# Process: [  275/ 4959 (5%)]	Loss: 1.6499	Acc:0.0000	Cost time:    6s	Estimated time:  106s
# Process: [  525/ 4959 (10%)]	Loss: 1.6223	Acc:0.0000	Cost time:   11s	Estimated time:   99s
# Process: [  775/ 4959 (15%)]	Loss: 1.5993	Acc:0.0000	Cost time:   17s	Estimated time:   94s
# Process: [ 1025/ 4959 (20%)]	Loss: 1.5814	Acc:0.0000	Cost time:   22s	Estimated time:   88s
# Process: [ 1275/ 4959 (25%)]	Loss: 1.5284	Acc:0.0000	Cost time:   28s	Estimated time:   83s
# Process: [ 1525/ 4959 (30%)]	Loss: 1.4690	Acc:0.0000	Cost time:   34s	Estimated time:   77s
# ...
