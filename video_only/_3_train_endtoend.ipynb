# %%
python main.py \
    --nClasses 5 \
    --path './backendGRU_every_frame/backendGRU_5.pt' \
    --dataset './lipread_npy/' \
    --mode 'finetuneGRU' \
    --every-frame 'True' \
    --batch-size 25 \
    --lr 3e-4 \
    --epochs 30 \
    --test ''
# Out:
# *** model has been successfully loaded! ***
# Load train part
# Load val part
# Load test part
#
# Statistics: train: 4959, val: 250, test: 250
# ----------
# Epoch 0/29
# Current Learning rate: [0.0003]
# main.py:109: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   running_loss += loss.data[0] * inputs.size(0)
# Process: [  275/ 4959 (5%)]	Loss: 0.1870	Acc:0.0000	Cost time:    5s	Estimated time:  101s
# Process: [  525/ 4959 (10%)]	Loss: 0.2620	Acc:0.0000	Cost time:   11s	Estimated time:   95s
# Process: [  775/ 4959 (15%)]	Loss: 0.3088	Acc:0.0000	Cost time:   16s	Estimated time:   90s
# Process: [ 1025/ 4959 (20%)]	Loss: 0.3193	Acc:0.0000	Cost time:   21s	Estimated time:   85s
# Process: [ 1275/ 4959 (25%)]	Loss: 0.3083	Acc:0.0000	Cost time:   27s	Estimated time:   79s
# Process: [ 1525/ 4959 (30%)]	Loss: 0.3028	Acc:0.0000	Cost time:   32s	Estimated time:   74s
# ...
